# %% [markdown]
# # This will be the Jupyter Notebook Answer Sheet for this project.

# %%
import pandas as pd
import sqlite3
con = sqlite3.connect('sqlite_db_pythonsqlite.db')
cur = con.cursor()

# %% [markdown]
# Q1: Some of the facilities charge a fee to members, but some do not.
# Write a SQL query to produce a list of the names of the facilities that do.
#
# A1: <br>
#
# ><code>SELECT name <br>
# >FROM Facilities <br>
# >WHERE membercost > 0; </code>

# %%
# Using only sqlite3.
cur.execute('SELECT name FROM Facilities WHERE membercost > 0')
no_fee_fac = cur.fetchall()
for fac in no_fee_fac:
    print(fac)
# Out:
# ('Tennis Court 1',)
# ('Tennis Court 2',)
# ('Massage Room 1',)
# ('Massage Room 2',)
# ('Squash Court',)

# %%
# Using sqlite3 and pandas.
no_fee_df = pd.read_sql_query('SELECT name FROM Facilities WHERE membercost > 0', con)
no_fee_df
# Out:
#              name
# 0  Tennis Court 1
# 1  Tennis Court 2
# 2  Massage Room 1
# 3  Massage Room 2
# 4    Squash Court

# %% [markdown]
# Q2: How many facilities do not charge a fee to members?
#
# A2: <br>
#
# ><code>SELECT COUNT(name) AS num_no_fee <br>
# >FROM Facilities <br>
# >WHERE membercost = 0; </code>

# %%
# Using only sqlite3.
cur.execute('SELECT COUNT(name) as num_no_fee FROM Facilities WHERE membercost = 0')
no_fee_count = cur.fetchall()
for fac in no_fee_count:
    print(fac)
# Out:
# (4,)

# %%
# Using sqlite3 and pandas.
no_fee_df = pd.read_sql_query('SELECT COUNT(name) AS num_no_fee FROM Facilities WHERE membercost = 0', con)
no_fee_df
# Out:
#    num_no_fee
# 0           4

# %% [markdown]
# Q3: Write an SQL query to show a list of facilities that charge a fee to members,
# where the fee is less than 20% of the facility's monthly maintenance cost.
# Return the facid, facility name, member cost, and monthly maintenance of the
# facilities in question.
#
# A3:<br>
#
# ><code>SELECT facid, name, membercost, monthlymaintenance <br>
# >FROM Facilities<br>
# >WHERE membercost > 0<br>
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;AND membercost < (monthlymaintenance * 0.2); </code>

# %%
# Using only sqlite3.
cur.execute('SELECT facid, name, membercost, monthlymaintenance FROM Facilities WHERE membercost > 0 AND membercost < (monthlymaintenance * 0.2)')
query3 = cur.fetchall()
for fac in query3:
    print(fac)
# Out:
# (0, 'Tennis Court 1', 5, 200)
# (1, 'Tennis Court 2', 5, 200)
# (4, 'Massage Room 1', 9.9, 3000)
# (5, 'Massage Room 2', 9.9, 3000)
# (6, 'Squash Court', 3.5, 80)

# %%
# Using sqlite3 and pandas.
query3df = pd.read_sql_query('SELECT facid, name, membercost, monthlymaintenance FROM Facilities WHERE membercost > 0 AND membercost < (monthlymaintenance * 0.2)', con)
query3df
# Out:
#    facid            name  membercost  monthlymaintenance
# 0      0  Tennis Court 1         5.0                 200
# 1      1  Tennis Court 2         5.0                 200
# 2      4  Massage Room 1         9.9                3000
# 3      5  Massage Room 2         9.9                3000
# 4      6    Squash Court         3.5                  80

# %% [markdown]
# Q4: Write an SQL query to retrieve the details of facilities with ID 1 and 5.
# Try writing the query without using the OR operator.
#
# A4:<br>
#
# ><code>SELECT *<br>
# >FROM Facilities<br>
# >WHERE facid IN (1, 5);</code>

# %%
# Using only sqlite3.
cur.execute('SELECT * FROM Facilities WHERE facid IN (1, 5)')
query4 = cur.fetchall()
for fac in query4:
    print(fac)
# Out:
# (1, 'Tennis Court 2', 5, 25, 8000, 200)
# (5, 'Massage Room 2', 9.9, 80, 4000, 3000)

# %%
# Using sqlite3 and pandas.
query4df = pd.read_sql_query('SELECT * FROM Facilities WHERE facid IN (1, 5)', con)
query4df
# Out:
#    facid            name  membercost  guestcost  initialoutlay  \
# 0      1  Tennis Court 2         5.0         25           8000
# 1      5  Massage Room 2         9.9         80           4000
#
#    monthlymaintenance
# 0                 200
# 1                3000

# %% [markdown]
# Q5: Produce a list of facilities, with each labelled as
# 'cheap' or 'expensive', depending on if their monthly maintenance cost is
# more than $100. Return the name and monthly maintenance of the facilities
# in question.
#
# A5:<br>
#
# ><code>SELECT name, monthlymaintenance,<br>
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;IIF(monthlymaintenance>100, "expensive", "cheap")<br>
# >FROM Facilities;</code>

# %%
# Using only sqlite3.
cur.execute('SELECT name, monthlymaintenance, IIF(monthlymaintenance>100, "expensive", "cheap") FROM Facilities')
query5 = cur.fetchall()
for fac in query5:
    print(fac)
# Out:
# ('Tennis Court 1', 200, 'expensive')
# ('Tennis Court 2', 200, 'expensive')
# ('Badminton Court', 50, 'cheap')
# ('Table Tennis', 10, 'cheap')
# ('Massage Room 1', 3000, 'expensive')
# ('Massage Room 2', 3000, 'expensive')
# ('Squash Court', 80, 'cheap')
# ('Snooker Table', 15, 'cheap')
# ('Pool Table', 15, 'cheap')

# %%
# Using sqlite3 and pandas.
query5df = pd.read_sql_query('SELECT name, monthlymaintenance, IIF(monthlymaintenance>100, "expensive", "cheap") FROM Facilities', con)
query5df
# Out:
#               name  monthlymaintenance  \
# 0   Tennis Court 1                 200
# 1   Tennis Court 2                 200
# 2  Badminton Court                  50
# 3     Table Tennis                  10
# 4   Massage Room 1                3000
# 5   Massage Room 2                3000
# 6     Squash Court                  80
# 7    Snooker Table                  15
# 8       Pool Table                  15
#
#   IIF(monthlymaintenance>100, "expensive", "cheap")
# 0                                         expensive
# 1                                         expensive
# 2                                             cheap
# 3                                             cheap
# 4                                         expensive
# 5                                         expensive
# 6                                             cheap
# 7                                             cheap
# 8                                             cheap

# %% [markdown]
# Q6: You'd like to get the first and last name of the last member(s)
# who signed up. Try not to use the LIMIT clause for your solution.
#
# A6:<br>
#
# ><code>SELECT firstname, surname FROM Members<br>
# >WHERE joindate =<br>
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(SELECT MAX(joindate) FROM Members);</code>

# %%
# Using only sqlite3.
cur.execute('SELECT firstname, surname FROM Members WHERE joindate = (SELECT MAX(joindate) FROM Members)')
query6 = cur.fetchall()
for fac in query6:
    print(fac)
# Out:
# ('Darren', 'Smith')

# %%
# Using sqlite3 and pandas.
query6df = pd.read_sql_query('SELECT firstname, surname FROM Members WHERE joindate = (SELECT MAX(joindate) FROM Members)', con)
query6df
# Out:
#   firstname surname
# 0    Darren   Smith

# %% [markdown]
# Q7: Produce a list of all members who have used a tennis court.
# Include in your output the name of the court, and the name of the member
# formatted as a single column. Ensure no duplicate data, and order by
# the member name.
#
# A7:<br>
#
# ><code>SELECT Facilities.name, Members.firstname || " " || Members.surname AS full_name<br>
# >FROM Bookings<br>
# >INNER JOIN Members ON Members.memid = Bookings.memid<br>
# >INNER JOIN Facilities ON Facilities.facid = Bookings.facid<br>
# >WHERE Bookings.facid IN (0, 1)<br>
# >GROUP BY full_name<br>
# >ORDER BY full_name;</code>

# %%
# Using only sqlite3.
cur.execute('SELECT Facilities.name, Members.firstname || " " || Members.surname AS full_name FROM Bookings INNER JOIN Members ON Members.memid = Bookings.memid INNER JOIN Facilities ON Facilities.facid = Bookings.facid WHERE Bookings.facid IN (0, 1) GROUP BY full_name ORDER BY full_name;')
query7 = cur.fetchall()
for fac in query7:
    print(fac)
# Out:
# ('Tennis Court 1', 'Anne Baker')
# ('Tennis Court 2', 'Burton Tracy')
# ('Tennis Court 1', 'Charles Owen')
# ('Tennis Court 2', 'Darren Smith')
# ('Tennis Court 1', 'David Farrell')
# ('Tennis Court 2', 'David Jones')
# ('Tennis Court 1', 'David Pinker')
# ('Tennis Court 1', 'Douglas Jones')
# ('Tennis Court 1', 'Erica Crumpet')
# ('Tennis Court 2', 'Florence Bader')
# ('Tennis Court 2', 'GUEST GUEST')
# ('Tennis Court 1', 'Gerald Butters')
# ('Tennis Court 2', 'Henrietta Rumney')
# ('Tennis Court 1', 'Jack Smith')
# ('Tennis Court 1', 'Janice Joplette')
# ('Tennis Court 2', 'Jemima Farrell')
# ('Tennis Court 1', 'Joan Coplin')
# ('Tennis Court 1', 'John Hunt')
# ('Tennis Court 1', 'Matthew Genting')
# ('Tennis Court 2', 'Millicent Purview')
# ('Tennis Court 2', 'Nancy Dare')
# ('Tennis Court 2', 'Ponder Stibbons')
# ('Tennis Court 2', 'Ramnaresh Sarwin')
# ('Tennis Court 2', 'Tim Boothe')
# ('Tennis Court 2', 'Tim Rownam')
# ('Tennis Court 2', 'Timothy Baker')
# ...

# %%
# Using sqlite3 and pandas.
query7df = pd.read_sql_query('SELECT Facilities.name, Members.firstname || " " || Members.surname AS full_name FROM Bookings INNER JOIN Members ON Members.memid = Bookings.memid INNER JOIN Facilities ON Facilities.facid = Bookings.facid WHERE Bookings.facid IN (0, 1) GROUP BY full_name ORDER BY full_name;', con)
query7df
# Out:
#               name          full_name
# 0   Tennis Court 1         Anne Baker
# 1   Tennis Court 2       Burton Tracy
# 2   Tennis Court 1       Charles Owen
# 3   Tennis Court 2       Darren Smith
# 4   Tennis Court 1      David Farrell
# 5   Tennis Court 2        David Jones
# 6   Tennis Court 1       David Pinker
# 7   Tennis Court 1      Douglas Jones
# 8   Tennis Court 1      Erica Crumpet
# 9   Tennis Court 2     Florence Bader
# 10  Tennis Court 2        GUEST GUEST
# 11  Tennis Court 1     Gerald Butters
# 12  Tennis Court 2   Henrietta Rumney
# 13  Tennis Court 1         Jack Smith
# 14  Tennis Court 1    Janice Joplette
# 15  Tennis Court 2     Jemima Farrell
# 16  Tennis Court 1        Joan Coplin
# 17  Tennis Court 1          John Hunt
# 18  Tennis Court 1    Matthew Genting
# 19  Tennis Court 2  Millicent Purview
# 20  Tennis Court 2         Nancy Dare
# 21  Tennis Court 2    Ponder Stibbons
# 22  Tennis Court 2   Ramnaresh Sarwin
# 23  Tennis Court 2         Tim Boothe
# ...

# %% [markdown]
# Q8: Produce a list of bookings on the day of 2012-09-14 which
# will cost the member (or guest) more than $30. Remember that guests have
# different costs to members (the listed costs are per half-hour 'slot'), and
# the guest user's ID is always 0. Include in your output the name of the
# facility, the name of the member formatted as a single column, and the cost.
# Order by descending cost, and do not use any subqueries.
#
# A8:<br>
#
# ><code>SELECT Facilities.name, Members.firstname || " " || Members.surname AS full_name, IIF(Members.memid = 0, Bookings.slots * Facilities.guestcost, Bookings.slots * Facilities.membercost) AS total_cost<br>
# >FROM Bookings<br>
# >INNER JOIN Members ON Members.memid = Bookings.memid<br>
# >INNER JOIN Facilities ON Facilities.facid = Bookings.facid<br>
# >WHERE Bookings.starttime LIKE '2012-09-14%'<br>
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;AND total_cost > 30<br>
# >GROUP BY full_name<br>
# >ORDER BY full_name</code>

# %%
# Using only sqlite3.

# Writing SQL code on Nopepad++ for convencience of formatting.
sql_file = open('query 8.sql', 'r')
sql_query = sql_file.read()
sql_file.close()

cur.execute(sql_query)
query_file = cur.fetchall()
for fac in query_file:
    print(fac)
# Out:
# ('Tennis Court 1', 'GUEST GUEST', 75)
# ('Massage Room 1', 'Jemima Farrell', 39.6)

# %%
# Using sqlite3 and pandas.
querydf = pd.read_sql_query(sql_query, con)
querydf
# Out:
#              name       full_name  total_cost
# 0  Tennis Court 1     GUEST GUEST        75.0
# 1  Massage Room 1  Jemima Farrell        39.6

# %% [markdown]
# Q9: This time, produce the same result as in Q8, but using a subquery.
#
# A9:<br>
#
# ><code></code>

# %%
# Using only sqlite3.

# Writing SQL code on Nopepad++ for convencience of formatting.
sql_file = open('query 9.sql', 'r')
sql_query = sql_file.read()
sql_file.close()

cur.execute(sql_query)
query_file = cur.fetchall()
for fac in query_file:
    print(fac)
# Out:
# ('Tennis Court 1', 'GUEST GUEST', 75)
# ('Massage Room 1', 'Jemima Farrell', 39.6)

# %%
# Using sqlite3 and pandas.
querydf = pd.read_sql_query(sql_query, con)
querydf
# Out:
#              name       full_name  total_cost
# 0  Tennis Court 1     GUEST GUEST        75.0
# 1  Massage Room 1  Jemima Farrell        39.6

# %% [markdown]
# Q10: Produce a list of facilities with a total revenue less than 1000.
# The output of facility name and total revenue, sorted by revenue. Remember
# that there's a different cost for guests and members!
#
# A10:<br>
#
# ><code>SELECT Facilities.name, ROUND(SUM(IIF(Bookings.memid != 0, Bookings.slots * Facilities.membercost, 0) + IIF(Bookings.memid != 0, Bookings.slots * Facilities.guestcost, 0)), 2) AS total_revenue<br>
# >FROM Bookings<br>
# >INNER JOIN Members ON Members.memid = Bookings.memid<br>
# >INNER JOIN Facilities ON Facilities.facid = Bookings.facid<br>
# >GROUP BY Facilities.name;</code>

# %%
# Using only sqlite3.

# Writing SQL code on Nopepad++ for convencience of formatting.
sql_file = open('query 10.sql', 'r')
sql_query = sql_file.read()
sql_file.close()

cur.execute(sql_query)
query_file = cur.fetchall()
for fac in query_file:
    print(fac)
# Out:
# ('Badminton Court', 18739.5)
# ('Massage Room 1', 121071.6)
# ('Massage Room 2', 18774.6)
# ('Pool Table', 4550.0)
# ('Snooker Table', 4540.0)
# ('Squash Court', 20783.0)
# ('Table Tennis', 4150.0)
# ('Tennis Court 1', 37785.0)
# ('Tennis Court 2', 36360.0)

# %%
# Using sqlite3 and pandas.
querydf = pd.read_sql_query(sql_query, con)
querydf
# Out:
#                   full_name
# 0               GUEST GUEST
# 1              Darren Smith
# 2               Tracy Smith
# 3                Tim Rownam
# 4           Janice Joplette
# 5            Gerald Butters
# 6              Burton Tracy
# 7                Nancy Dare
# 8                Tim Boothe
# 9           Ponder Stibbons
# 10             Charles Owen
# 11              David Jones
# 12               Anne Baker
# 13           Jemima Farrell
# 14               Jack Smith
# 15           Florence Bader
# 16            Timothy Baker
# 17             David Pinker
# 18          Matthew Genting
# 19           Anna Mackenzie
# 20              Joan Coplin
# 21         Ramnaresh Sarwin
# 22            Douglas Jones
# 23         Henrietta Rumney
# 24            David Farrell
# 25  Henry Worthington-Smyth
# 26        Millicent Purview
# 27      Hyacinth Tupperware
# 28                John Hunt
# 29            Erica Crumpet
# 30             Darren Smith

# %% [markdown]
# Q11: Produce a report of members and who recommended them in alphabetic surname,firstname order
#
# A11:<br>
#
# ><code>SELECT a.firstname || " " || a.surname AS full_name, b.firstname || " " || b.surname AS recommended_by<br>
# >FROM Members a<br>
# >INNER JOIN Members b ON b.memid = a.recommendedby<br>
# >ORDER BY a.surname;</code>

# %%
# Using only sqlite3.

# Writing SQL code on Nopepad++ for convencience of formatting.
sql_file = open('query 11.sql', 'r')
sql_query = sql_file.read()
sql_file.close()

cur.execute(sql_query)
query_file = cur.fetchall()
for fac in query_file:
    print(fac)
# Out:
# ('Florence Bader', 'Ponder Stibbons')
# ('Anne Baker', 'Ponder Stibbons')
# ('Timothy Baker', 'Jemima Farrell')
# ('Tim Boothe', 'Tim Rownam')
# ('Gerald Butters', 'Darren Smith')
# ('Joan Coplin', 'Timothy Baker')
# ('Erica Crumpet', 'Tracy Smith')
# ('Nancy Dare', 'Janice Joplette')
# ('Matthew Genting', 'Gerald Butters')
# ('John Hunt', 'Millicent Purview')
# ('David Jones', 'Janice Joplette')
# ('Douglas Jones', 'David Jones')
# ('Janice Joplette', 'Darren Smith')
# ('Anna Mackenzie', 'Darren Smith')
# ('Charles Owen', 'Darren Smith')
# ('David Pinker', 'Jemima Farrell')
# ('Millicent Purview', 'Tracy Smith')
# ('Henrietta Rumney', 'Matthew Genting')
# ('Ramnaresh Sarwin', 'Florence Bader')
# ('Jack Smith', 'Darren Smith')
# ('Ponder Stibbons', 'Burton Tracy')
# ('Henry Worthington-Smyth', 'Tracy Smith')

# %%
# Using sqlite3 and pandas.
querydf = pd.read_sql_query(sql_query, con)
querydf
# Out:
#               name  SUM(IIF(Bookings.memid != 0, slots, 0))
# 0  Badminton Court                                     1086
# 1   Massage Room 1                                      884
# 2   Massage Room 2                                       54
# 3       Pool Table                                      856
# 4    Snooker Table                                      860
# 5     Squash Court                                      418
# 6     Table Tennis                                      794
# 7   Tennis Court 1                                      957
# 8   Tennis Court 2                                      882

# %% [markdown]
# Q12: Find the facilities with their usage by member, but not guests
#
# A12:<br>
#
# ><code>SELECT Facilities.name, SUM(IIF(Bookings.memid != 0, slots, 0)) AS slot_usage<br>
# >FROM Bookings<br>
# >INNER JOIN Facilities ON Facilities.facid = Bookings.facid<br>
# >GROUP BY Facilities.name;</code>

# %%
# Using only sqlite3.

# Writing SQL code on Nopepad++ for convencience of formatting.
sql_file = open('query 12.sql', 'r')
sql_query = sql_file.read()
sql_file.close()

cur.execute(sql_query)
query_file = cur.fetchall()
for fac in query_file:
    print(fac)
# Out:
# ('Badminton Court', 1086)
# ('Massage Room 1', 884)
# ('Massage Room 2', 54)
# ('Pool Table', 856)
# ('Snooker Table', 860)
# ('Squash Court', 418)
# ('Table Tennis', 794)
# ('Tennis Court 1', 957)
# ('Tennis Court 2', 882)

# %%
# Using sqlite3 and pandas.
querydf = pd.read_sql_query(sql_query, con)
querydf
# Out:
#               name  slot_usage
# 0  Badminton Court        1086
# 1   Massage Room 1         884
# 2   Massage Room 2          54
# 3       Pool Table         856
# 4    Snooker Table         860
# 5     Squash Court         418
# 6     Table Tennis         794
# 7   Tennis Court 1         957
# 8   Tennis Court 2         882

# %% [markdown]
# Q13: Find the facilities usage by month, but not guests.
#
# A13:<br>
#
# ><code>SELECT SUBSTR(Bookings.starttime, 6, 2) || '/' || SUBSTR(Bookings.starttime, 1, 4) AS month, Facilities.name, SUM(IIF(Bookings.memid != 0, slots, 0)) AS slot_usage<br>
# >FROM Bookings<br>
# >INNER JOIN Facilities ON Facilities.facid = Bookings.facid<br>
# >GROUP BY month, Facilities.name<br>
# >ORDER BY month, Facilities.name;</code>

# %%
# Using only sqlite3.

# Writing SQL code on Nopepad++ for convencience of formatting.
sql_file = open('query 13.sql', 'r')
sql_query = sql_file.read()
sql_file.close()

cur.execute(sql_query)
query_file = cur.fetchall()
for fac in query_file:
    print(fac)
# Out:
# ('07/2012', 'Badminton Court', 165)
# ('07/2012', 'Massage Room 1', 166)
# ('07/2012', 'Massage Room 2', 8)
# ('07/2012', 'Pool Table', 110)
# ('07/2012', 'Snooker Table', 140)
# ('07/2012', 'Squash Court', 50)
# ('07/2012', 'Table Tennis', 98)
# ('07/2012', 'Tennis Court 1', 201)
# ('07/2012', 'Tennis Court 2', 123)
# ('08/2012', 'Badminton Court', 414)
# ('08/2012', 'Massage Room 1', 316)
# ('08/2012', 'Massage Room 2', 18)
# ('08/2012', 'Pool Table', 303)
# ('08/2012', 'Snooker Table', 316)
# ('08/2012', 'Squash Court', 184)
# ('08/2012', 'Table Tennis', 296)
# ('08/2012', 'Tennis Court 1', 339)
# ('08/2012', 'Tennis Court 2', 345)
# ('09/2012', 'Badminton Court', 507)
# ('09/2012', 'Massage Room 1', 402)
# ('09/2012', 'Massage Room 2', 28)
# ('09/2012', 'Pool Table', 443)
# ('09/2012', 'Snooker Table', 404)
# ('09/2012', 'Squash Court', 184)
# ('09/2012', 'Table Tennis', 400)
# ('09/2012', 'Tennis Court 1', 417)
# ('09/2012', 'Tennis Court 2', 414)

# %%
# Using sqlite3 and pandas.
querydf = pd.read_sql_query(sql_query, con)
querydf
# Out:
#       month             name  slot_usage
# 0   07/2012  Badminton Court         165
# 1   07/2012   Massage Room 1         166
# 2   07/2012   Massage Room 2           8
# 3   07/2012       Pool Table         110
# 4   07/2012    Snooker Table         140
# 5   07/2012     Squash Court          50
# 6   07/2012     Table Tennis          98
# 7   07/2012   Tennis Court 1         201
# 8   07/2012   Tennis Court 2         123
# 9   08/2012  Badminton Court         414
# 10  08/2012   Massage Room 1         316
# 11  08/2012   Massage Room 2          18
# 12  08/2012       Pool Table         303
# 13  08/2012    Snooker Table         316
# 14  08/2012     Squash Court         184
# 15  08/2012     Table Tennis         296
# 16  08/2012   Tennis Court 1         339
# 17  08/2012   Tennis Court 2         345
# 18  09/2012  Badminton Court         507
# 19  09/2012   Massage Room 1         402
# 20  09/2012   Massage Room 2          28
# 21  09/2012       Pool Table         443
# ...
